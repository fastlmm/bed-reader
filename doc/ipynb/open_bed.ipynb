# %% [markdown]
# ### Task: Simplest Read All

# %%
import os
os.chdir(r'D:\OneDrive\programs\pstsgkit\tests')

# %%
from sgkit_plink._open_bed import open_bed

val = open_bed('datasets/snpgen.bed').read(force_python_only=True)
print(val.shape, val.dtype)
val
# Out:
# (1000, 5) int8
# array([[   2, -127,    2,    2,    2],
#        [   2,    2,    2,    2,    2],
#        [-127,    2, -127,    2, -127],
#        ...,
#        [-127, -127,    2,    2, -127],
#        [   2,    2,    2,    2, -127],
#        [   2,    2,    2,    2,    2]], dtype=int8)

# %% [markdown]
# #### Discussion
#
# * This is running code at https://github.com/CarlKCarlK/sgkit-plink/commit/b1ab9e04
# * In this example, it avoids parsing the metadata (samples and variant names, etc)
#    * All metadata parsing is now lazy
#    * In this case, it does a one-time, fast, line count of the \*.fam and \*.bim files instead of a parse.
# * "close()" is not needed because there is no longer a persistent file pointer
#
# *In the future*
#
# * *force_python_only* won't be needed
# * Final import will be something like 'from sgkit_plink import open_bed

# %% [markdown]
# ### Task: sgkit's use case: Reading data in batches when we know the dimensions

# %%
import numpy as np

with open_bed('datasets/all_chr.maf0.001.N300.bed',iid=300,sid=1015) as bed:
    batch_size = 100
    for start in range(0,bed.sid_count,batch_size):
        val = bed.read(index=np.s_[:,start:start+batch_size],force_python_only=True)
        print(val.shape)
# Out:
# (300, 100)
# (300, 100)
# (300, 100)
# (300, 100)
# (300, 100)
# (300, 100)
# (300, 100)
# (300, 100)
# (300, 100)
# (300, 100)
# (300, 15)

# %% [markdown]
# #### Discussion
#
# * This is sgkit's use case
# * The \*.fam and \*.bim files are never read.
# * I'm thinking about adding an \_\_item\_\_ method
#    * But PySnpTools needs to specify a dtype and order on every read

# %% [markdown]
# ### Task: Find the mean value for every chromosome (excluding missing values)

# %%
with open_bed('datasets/all_chr.maf0.001.N300.bed') as bed:
    for chrom in np.unique(bed.chromosome): # pos[:,0] is chrom number
        val = bed.read(index=np.s_[:,bed.chromosome==chrom],dtype='float32',force_python_only=True)
        print(f'chromo {int(chrom)} mean: {np.nanmean(val):0.4}')
# Out:
# chromo 1 mean: 0.1631
# chromo 10 mean: 0.2113
# chromo 11 mean: 0.2175
# chromo 12 mean: 0.208
# chromo 13 mean: 0.1667
# chromo 14 mean: 0.2361
# chromo 15 mean: 0.1573
# chromo 16 mean: 0.1735
# chromo 17 mean: 0.1155
# chromo 18 mean: 0.1494
# chromo 19 mean: 0.234
# chromo 2 mean: 0.1015
# chromo 20 mean: 0.1828
# chromo 21 mean: 0.126
# chromo 22 mean: 0.2173
# chromo 23 mean: 0.3713
# chromo 3 mean: 0.1927
# chromo 4 mean: 0.318
# chromo 5 mean: 0.2038
# chromo 6 mean: 0.1897
# chromo 7 mean: 0.185
# chromo 8 mean: 0.191
# chromo 9 mean: 0.204

# %% [markdown]
# #### Discussion
#
# * This examples shows what a NumPy-inspired API is good at.
# * Lazy metadata means, the '.bim' file is parsed (one time) here while the '.fam' file is merely line-counted (one time).

# %% [markdown]
# ### Punt Slicing Metadata?
#
# * My plan is to continue to ignore the rest of the metadata info (e.g., parent info, phenotype in \*.fam) because:
#   * I've never had anyone request it
#   * They can parse it from \*.fam and \*.bim if they need it
# * However, I can imagine a way to efficently slice into metadata, but is this ability needed?

# %%
#hypothetical! doesn't run. may not implement

with open_bed('datasets/all_chr.maf0.001.N300.bed') as bed:
    batch_size = 100
    
    # The first time .sid_count is called, C++ code would (in one pass)
    # count the lines in *.bim and return the offsets for sqrt(#lines) random lines.
    # For example, if there turns out to be 1 million variants, 
    # we'd remember offsets to a random 1000 of them.
    
    for start in range(0,bed.sid_count,batch_size):
        #'batch' becomes an open_bed object for just a subset of the data
        batch = bed[:,start:start+batch_size]
        print(batch.sid) #We can find all the variant names in batch in Order(sqrt(#original_lines))
        val = batch.read()
        print(val.shape)
        
# Could do for *.fam and *.bim

# %% [markdown]
# #### Discussion
#
# * This doesn't require a cache file
# * It is low memory and fast
# * But ...
#   * Is it needed by anyone?
#   * If it is needed, can't they just use sgkit and its dask files?

# %% [markdown]
# ### random stuff

# %%
# %%time
filename = r'M:\deldir\genbgen\2\merged_487400x220000.1.bed'
bed = open_bed(filename)
bed.shape
# Out:
# Wall time: 3.12 s
# (487400, 220000)

# %%
bed.read(np.s_[:,100*1000:100*1000+10])
# Out:
# array([[   2, -127,    2, ...,    2,    2,    2],
#        [   2, -127,    2, ...,    2, -127,    2],
#        [   2, -127,    2, ...,    2,    2,    2],
#        ...,
#        [   2,    2,    2, ...,    2,    2,    2],
#        [   2,    2, -127, ...,    2, -127,    2],
#        [   2, -127,    2, ...,    2,    2, -127]], dtype=int8)

# %%
bed.chromosome
# Out:
# array(['1', '1', '1', ..., '1', '1', '1'], dtype='<U1')

# %%
bed.iid
# Out:
# array([['1', 'sample_0'],
#        ['2', 'sample_1'],
#        ['3', 'sample_2'],
#        ...,
#        ['487398', 'sample_48739'],
#        ['487399', 'sample_48739'],
#        ['487400', 'sample_48739']], dtype='<U12')

# %%
sum(range(1000*1000))
# Out:
# 499999500000

# %%
from pysnptools.util.mapreduce1 import map_reduce
from pysnptools.util.mapreduce1.runner import LocalMultiThread, LocalMultiProc, Local
import time

def slow_square(x):
    time.sleep(1)
    return x*x

def square_sum(count,runner=None):
    ss= map_reduce(range(count),
               mapper=slow_square,
               reducer=sum,
               runner=runner)
    return ss

square_sum(10)
# Out:
# 285

# %%
# %%time

square_sum(10,runner=Local())
# Out:
# Wall time: 10.1 s
# 285

# %%
# %%time

square_sum(100,runner=LocalMultiThread(10))
# Out:
# Wall time: 10.1 s
# 328350

# %%
def thread_read(filename, runner):
    with open_bed(filename) as bed:
        bed.shape #causes the lazy meta to read the # lines in the two metadata files
        batch_size = 100
        def read_and_report(start):
            print(start)
            val = bed.read(index=np.s_[:,start:start+batch_size],force_python_only=True)
            return val.shape

        report = map_reduce(range(0,bed.sid_count,batch_size),
                   mapper=read_and_report,
                   runner=runner)
        return report

# %%
# %%time

thread_read('datasets/all_chr.maf0.001.N300.bed', runner=Local())
# Out:
# 0
# 100
# 200
# 300
# 400
# 500
# 600
# 700
# 800
# 900
# 1000
# Wall time: 67 ms
# [(300, 100),
#  (300, 100),
#  (300, 100),
#  (300, 100),
#  (300, 100),
#  (300, 100),
#  (300, 100),
#  (300, 100),
#  (300, 100),
#  (300, 100),
#  (300, 15)]

# %%
# %%time

thread_read('datasets/all_chr.maf0.001.N300.bed', runner=LocalMultiThread(10))
# Out:
# 0100
#
# 200
# 300
# 400
# 500
# 600
# 700
# 800
# 900
# 1000
# Wall time: 93 ms
# [(300, 100),
#  (300, 100),
#  (300, 100),
#  (300, 100),
#  (300, 100),
#  (300, 100),
#  (300, 100),
#  (300, 100),
#  (300, 100),
#  (300, 100),
#  (300, 15)]

# %%
bigfile = r'M:\deldir\genbgen\2\merged_487400x220000.1.bed'

# %%
# %%time

thread_read(bigfile, runner=Local())
# Out:
# 0
# 100
# 200
# 300
# 400
# 500
# 600
# 700
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <timed eval> in <module>
#
# <ipython-input-62-a5636cae0b2f> in thread_read(filename, runner)
#      10         report = map_reduce(range(0,bed.sid_count,batch_size),
#      11                    mapper=read_and_report,
# ---> 12                    runner=runner)
#      13         return report
#      14
#
# D:\OneDrive\programs\pstsgkit\pysnptools\util\mapreduce1\mapreduce.py in map_reduce(input_seq, mapper, reducer, input_files, output_files, name, runner, nested)
#     203         runner = Local()
#     204
# --> 205     result = runner.run(dist)
#     206     return result
#     207
#
# D:\OneDrive\programs\pstsgkit\pysnptools\util\mapreduce1\runner\local.py in run(self, distributable)
#      49     def run(self, distributable):
#      50         _JustCheckExists().input(distributable)
# ---> 51         result = _run_all_in_memory(distributable)
#      52         _JustCheckExists().output(distributable)
#      53         return result
#
# D:\OneDrive\programs\pstsgkit\pysnptools\util\mapreduce1\runner\__init__.py in _run_all_in_memory(work)
#      28         work_sequence = work.work_sequence()
#      29         result_sequence = work_sequence_to_result_sequence(work_sequence)
# ---> 30         return work.reduce(result_sequence)
#      31
#      32
#
# D:\OneDrive\programs\pstsgkit\pysnptools\util\mapreduce1\mapreduce.py in reduce(self, output_seq)
#      76         '''
#      77
# ---> 78         return self.reducer(output_seq)
#      79
#      80
#
# D:\OneDrive\programs\pstsgkit\pysnptools\util\mapreduce1\runner\__init__.py in work_sequence_to_result_sequence(work_sequence)
#      12     for work in work_sequence:
#      13         if callable(work):
# ---> 14             result = work()
#      15         else:
#      16             result = _run_all_in_memory(work)
#
# D:\OneDrive\programs\pstsgkit\pysnptools\util\mapreduce1\mapreduce.py in <lambda>(i, input_arg)
#      64                 #logging.debug("\nexecuting %i" % i)
#      65                 with _MapReduce._dyn_vars(is_in_nested=False):
# ---> 66                     yield lambda i=i, input_arg=input_arg: self.dowork(i, input_arg)  # the 'i=i',etc is need to get around a strangeness in Python
#      67             else:
#      68                 assert self.nested is not None, "real assert"
#
# D:\OneDrive\programs\pstsgkit\pysnptools\util\mapreduce1\mapreduce.py in dowork(self, i, input_arg)
#      91         #logging.debug("\nexecuting {0}".format(input_arg))
#      92         work = lambda : self.mapper(input_arg)
# ---> 93         result = _run_all_in_memory(work)
#      94         return result
#      95
#
# D:\OneDrive\programs\pstsgkit\pysnptools\util\mapreduce1\runner\__init__.py in _run_all_in_memory(work)
#      23     '''
#      24     if callable(work):
# ---> 25         return work()
#      26     else:
#      27         assert hasattr(work,"work_sequence"), "Your work item doesn't have a work_sequence. This can be caused by having 'map_reduce(nested=something,...)' where you should have 'map_reduce(mapper=something,...)' because the 'something' is not a nested 'map_reduce'. The exception can also be caused by giving a 'runner' on an inner, nested map_reduce."
#
# D:\OneDrive\programs\pstsgkit\pysnptools\util\mapreduce1\mapreduce.py in <lambda>()
#      90         #logging.info("{0}, {1}".format(len(train_snp_idx), len(test_snp_idx)))
#      91         #logging.debug("\nexecuting {0}".format(input_arg))
# ---> 92         work = lambda : self.mapper(input_arg)
#      93         result = _run_all_in_memory(work)
#      94         return result
#
# <ipython-input-62-a5636cae0b2f> in read_and_report(start)
#       5         def read_and_report(start):
#       6             print(start)
# ----> 7             val = bed.read(index=np.s_[:,start:start+batch_size],force_python_only=True)
#       8             return val.shape
#       9
#
# D:\OneDrive\programs\sgkit-plink\sgkit_plink\_open_bed.py in read(self, index, dtype, order, force_python_only)
#     640     def shape(self):
#     641         return (len(self.iid), len(self.sid))
# --> 642
#     643     def read(
#     644         self,
#
# D:\OneDrive\programs\sgkit-plink\sgkit_plink\_open_bed.py in _read(self, iid_index_or_none, sid_index_or_none, order, dtype, force_python_only)
#     609                     val[2::4, SNPsIndex : SNPsIndex + 1][bytes >= 48] = byteThree
#     610                     bytes = np.mod(bytes, 16)
# --> 611                     val[1::4, SNPsIndex : SNPsIndex + 1] = byteZero
#     612                     val[1::4, SNPsIndex : SNPsIndex + 1][bytes >= 4] = missing
#     613                     val[1::4, SNPsIndex : SNPsIndex + 1][bytes >= 8] = 1
#
# KeyboardInterrupt:

# %%
# %%time

thread_read(bigfile, runner=LocalMultiThread(10))
# Out:
# 0
# 22000
# 44000
# 66000
# 88000
# 110000
# 132000
# 154000
# 176000
# 198000
# 661008810044100
#
# 22100176100
#
#
# 154100198100
# 100
# 110100
# 132100
#
# 20044200
#
# 8820066200
#
# 132200
# 110200176200
# 198200154200
#
#
# 22200
# 198300
# 88300110300
#
# 132300
# 66300154300
# 17630022300
#
# 300
# 44300
#
# 198400
# 11040088400
# 154400
#
# 66400400
# 17640044400
# 22400
#
#
# 132400
# 198500
# 176500
# 110500
# 1545004450022500
#
# 6650013250088500
# 500
#
#
#
# 198600
# 6660088600600
# 110600176600
#
# 132600
#
# 44600
# 22600
#
# 154600
# 198700
# 8870066700
#
# 44700
# 176700700
#
# 154700110700
#
# 13270022700
#
# 198800
# 13280066800
# 154800
# 800
# 88800110800
#
# 17680044800
#
# 22800
#
# 198900
# 15490066900
#
# 8890022900132900
#
# 110900
#
# 176900
# 19900044900900
#
#
# 670002300089000
#
#
# 45000
# 177000155000
# 1000
#
# 133000199100111000
#
#
# 67100
# 199200
# 89100
# 15510045100
#
# 177100
# 133100
# 23100
# 1111001100
#
# 67200
# 199300
# 89200
# 177200155200
#
# 2320045200
#
# 133200
# 1200111200
#
# 67300
# 199400
# 89300
# 23300
# 177300
# 155300
# 45300
# 133300
# 1300
# 111300
# 67400
# 199500
# 89400
# 177400
# 2340045400
#
# 155400
# 111400
# 1400133400
#
# 67500
# 199600
# 89500
# 155500
# 23500177500
#
# 111500
# 45500
# 1335001500
#
# 67600
# 89600
# 199700
# 1600
# 111600
# 133600
# 155600
# 45600
# 177600
# 23600
# 67700
# 89700
# 199800
# 1700155700
#
# 111700
# 133700
# 45700
# 23700
# 177700
# 67800
# 89800
# 199900
# 1800
# 133800
# 155800
# 6790045800
#
# 177800
# 111800
# 23800
# 200000
# 89900
# 1900
# 133900
# 155900
# 68000
# 11190045900
# 200100
# 17790023900
#
#
# 90000
# 2000
# 68100
# 200200
# 13400090100
#
# 112000
# 17800024000
#
# 156000
# 46000
# 2100
# 68200
# 134100
# 90200
# 200300
# 112100
# 2410015610046100
#
#
# 178100
# 2200
# 68300
# 90300
# 200400
# 134200
# 112200
# 24200
# 156200
# 178200
# 46200
# 2300
# 200500
# 68400
# 134300
# 90400
# 24300
# 156300
# 46300112300
#
# 178300
# 2400
# 200600
# 68500
# 134400
# 90500
# 112400
# 156400
# 24400
# 46400
# 178400
# 2500
# 200700
# 68600
# 134500
# 90600
# 112500
# 24500
# 46500
# 156500
# 2600178500
#
# 200800
# 68700
# 134600
# 90700
# 112600
# 24600156600
#
# 200900
# 46600
# 270068800
#
# 178600
# 90800
# 134700
# 112700
# 201000
# 68900
# 156700
# 178700
# 46700
# 280090900
#
# 24700
# 134800
# 201100
# 112800
# 69000
# 91000
# 1568002900
#
# 178800
# 4680024800
#
# 134900
# 201200
# 112900
# 69100
# 91100
# 3000
# 46900178900
#
# 156900
# 24900
# 135000
# 201300
# 11300069200
#
# 91200
# 3100157000
#
# 17900047000
#
# 25000
# 135100
# 201400
# 69300
# 113100
# 91300
# 3200
# 4710025100
#
# 157100
# 179100
# 201500
# 135200
# 69400
# 113200
# 91400
# 3300
# 157200
# 179200201600
#
# 25200
# 47200
# 69500
# 135300
# 113300
# 91500
# 201700
# 3400
# 157300
# 179300
# 25300
# 69600
# 47300
# 135400
# 113400
# 91600
# 201800
# 157400
# 3500
# 69700
# 179400
# 25400
# 135500
# 47400
# 91700
# 113500
# 201900
# 157500
# 3600
# 69800
# 17950025500
#
# 91800
# 47500
# 135600
# 113600
# 202000
# 157600
# 69900
# 3700
# 91900
# 135700
# 113700
# 47600
# 25600179600
#
# 202100
# 157700
# 70000
# 3800
# 92000
# 47700
# 179700
# 135800
# 25700
# 202200
# 113800
# 157800
# 70100
# 3900
# 202300
# 92100
# 179800
# 47800
# 25800
# 70200
# 135900
# 113900
# 157900
# 4000
# 202400
# 92200
# 70300
# 25900136000179900
#
#
# 47900
# 114000
# 4100
# 92300
# 158000
# 202500
# 70400
# 92400
# 202600
# 26000
# 180000
# 136100
# 11410048000
#
# 70500
# 158100
# 4200
# 202700
# 92500
# 70600
# 136200
# 114200
# 4810018010026100
#
#
# 4300
# 20280092600
#
# 158200
# 70700
# 136300
# 202900
# 92700
# 114300
# 48200
# 180200
# 26200
# 70800
# 4400
# 158300
# 203000
# 92800
# 114400
# 136400
# 70900
# 4500
# 180300
# 48300
# 26300
# 158400
# 203100
# 92900
# 114500
# 71000
# 136500
# 4600
# 180400
# 48400
# 26400
# 203200
# 93000
# 158500
# 71100
# 114600
# 1366004700
#
# 180500
# 26500
# 203300
# 48500
# 93100
# 71200
# 158600
# 114700
# 180600
# 203400
# 4800
# 26600
# 136700
# 48600
# 71300
# 93200
# 158700
# 203500
# 180700
# 1148004900
#
# 48700
# 26700
# 136800
# 93300
# 71400
# 158800
# 203600
# 180800
# 4880026800
#
# 114900
# 5000
# 136900
# 71500
# 93400
# 158900
# 203700
# 180900
# 26900
# 48900
# 71600
# 115000137000
# 93500
#
# 5100
# 159000
# 203800
# 181000
# 49000
# 2700071700
#
# 93600
# 115100
# 5200
# 137100
# 203900
# 159100
# 181100
# 49100
# 71800
# 27100
# 93700
# 204000
# 159200
# 115200
# 137200
# 5300
# 181200
# 71900
# 49200
# 27200
# 93800
# 204100
# 137300159300
#
# 5400
# 115300
# 181300
# 72000
# 49300
# 27300
# 93900
# 204200
# 159400
# 1374001154005500
#
#
# 72100
# 181400
# 94000
# 49400
# 27400
# 204300
# 159500
# 137500
# 115500
# 5600
# 72200
# 94100
# 49500
# 27500
# 181500
# 204400
# 159600
# 137600
# 115600
# 72300
# 5700
# 27600
# 94200
# 18160049600
#
# 204500
# 159700
# 137700
# 115700
# 72400
# 5800
# 2770094300
#
# 18170049700
#
# 204600
# 159800
# 137800
# 115800
# 72500
# 5900
# 204700
# 94400
# 49800
# 27800181800
#
# 159900
# 137900
# 115900
# 72600
# 6000
# 18190020480094500
#
#
# 27900
# 49900160000
#
# 138000
# 116000
# 72700
# 6100
# 204900
# 94600
# 182000
# 50000
# 28000
# 160100
# 116100
# 138100
# 72800
# 6200
# 205000
# 94700
# 182100
# 28100
# 50100
# 160200
# 138200116200
#
# 72900
# 6300
# 205100
# 94800
# 182200
# 50200
# 28200
# 160300
# 116300
# 138300
# 73000
# 6400
# 205200
# 94900
# 18230050300
#
# 28300
# 73100116400
#
# 160400
# 138400
# 6500
# 205300
# 95000
# 182400
# 73200
# 50400
# 116500
# 160500
# 28400
# 138500
# 6600
# 95100
# 205400
# 73300
# 182500
# 50500
# 116600
# 28500160600
#
# 138600
# 95200205500
#
# 6700
# 73400
# 50600
# 182600
# 205600
# 28600116700
#
# 160700138700
#
# 95300
# 6800
# 73500
# 50700
# 182700
# 954001388006900
# 205700
#
#
# 28700160800
#
# 116800
# 73600
# 50800
# 182800
# 20580095500
#
# 138900160900
# 116900
# 28800
# 7000
#
# 73700
# 50900
# 182900
# 710095600
# 139000205900
#
# 11700016100028900
#
#
#
# 73800
# 51000
# 183000
# 20600029000
#
# 73900
# 161100117100
# 95700139100
#
#
# 7200
# 51100
# 183100
# 206100
# 74000
# 95800
# 29100
# 117200
# 1392007300
#
# 161200
# 51200
# 183200
# 206200
# 74100
# 95900
# 29200
# 117300
# 161300
# 7400
# 139300
# 183300
# 51300
# 206300
# 74200
# 96000
# 29300
# 117400
# 161400
# 183400
# 7500
# 139400
# 51400
# 206400
# 74300
# 96100
# 29400
# 117500
# 161500
# 183500
# 51500
# 7600
# 206500
# 139500
# 74400
# 96200
# 29500
# 117600
# 161600
# 183600
# 51600206600
#
# 139600
# 7450096300
#
# 7700
# 29600
# 117700
# 161700
# 206700
# 183700
# 51700
# 7460096400
# 7800
# 139700
#
# 29700
# 117800
# 161800
# 206800
# 183800
# 7470096500
# 51800139800
#
# 29800
# 7900
#
# 117900
# 161900
# 74800
# 51900
# 139900
# 96600
# 183900
# 206900800029900
#
#
# 118000
# 162000
# 74900
# 140000
# 30000
# 207000
# 52000
# 8100
# 184000
# 96700
# 118100
# 162100
# 75000
# 140100
# 207100
# 30100
# 1841009680052100
#
#
# 8200
# 118200
# 162200
# 75100
# 207200
# 140200
# 184200
# 162300
# 30200
# 96900
# 118300
# 522008300
#
# 75200
# 207300
# 184300140300
#
# 162400
# 97000
# 30300
# 75300
# 52300
# 118400
# 8400
# 207400
# 184400
# 162500
# 140400
# 97100
# 30400
# 52400
# 850075400
#
# 118500
# 207500
# 184500
# 140500
# 162600
# 97200
# 30500
# 52500
# 75500
# 8600
# 118600
# 207600
# 162700
# 184600
# 97300140600
#
# 75600
# 30600
# 207700
# 52600
# 118700
# 8700
# 97400184700
#
# 162800
# 140700
# 207800
# 75700880030700
#
#
# 52700
# 118800
# 97500
# 184800
# 162900140800
#
# 207900
# 75800
# 308008900
# 11890052800
#
#
# 97600
# 184900
# 163000
# 140900
# 208000
# 75900
# 9000
# 52900
# 11900030900
#
# 97700
# 163100
# 185000
# 141000
# 208100
# 76000
# 9100
# 119100
# 31000
# 97800
# 53000
# 163200
# 185100
# 141100
# 208200
# 76100
# 9200
# 97900
# 119200
# 31100
# 53100
# 163300
# 185200208300
#
# 141200
# 76200
# 98000
# 9300
# 3120053200119300
#
#
# 163400
# 76300
# 141300208400185300
#
#
# 98100
# 9400
# 31300
# 53300
# 119400
# 76400163500
#
# 208500141400
# 185400
#
# 98200
# 31400
# 53400
# 9500119500
#
# 14150018550076500208600
#
#
#
# 163600
# 98300
# 31500
# 53500
# 9600
# 119600
# 76600208700185600163700
#
#
#
# 141600
# 98400
# 31600
# 53600
# 119700
# 9700
# 76700
# 185700
# 208800
# 98500141700
#
# 163800
# 3170053700
#
# 119800
# 9800
# 76800
# 185800
# 20890098600163900
# 141800
#
#
# 53800
# 31800
# 9900
# 119900
# 76900
# 209000
# 185900
# 98700
# 164000
# 141900
# 120000
# 53900
# 31900
# 10000
# 77000
# 98800
# 209100
# 186000
# 164100
# 142000
# 54000
# 32000
# 120100
# 10100
# 77100
# 98900
# 209200
# 186100
# 142100
# 164200
# 54100
# 32100
# 10200
# 120200
# 77200
# 99000
# 209300
# 186200
# 142200
# 164300
# 54200
# 32200
# 10300
# 120300
# 9910077300
#
# 209400
# 186300
# 142300
# 164400
# 54300
# 32300
# 10400
# 120400
# 77400
# 99200
# 209500
# 186400
# 142400164500
#
# 54400
# 32400
# 10500
# 7750099300
#
# 209600
# 120500
# 186500
# 164600
# 142500
# 54500
# 32500
# 10600
# 99400209700
#
# 120600
# 164700186600
# 77600
#
# 142600
# 54600
# 32600
# 10700
# 209800
# 99500
# 164800
# 120700
# 186700
# 77700
# 142700
# 32700
# 54700
# 10800
# 99600209900
#
# 164900
# 12080077800
# 186800
#
# 14280032800
#
# 5480010900
#
# 21000099700
#
# 77900165000120900
#
#
# 186900
# 32900
# 14290011000
#
# 54900
# 99800
# 210100
# 78000
# 165100
# 187000
# 121000
# 11100
# 143000
# 3300055000210200
# 99900
#
#
# 78100
# 165200
# 187100
# 121100
# 3310011200
#
# 55100100000210300
#
# 143100
#
# 78200
# 165300
# 187200
# 121200
# 210400
# 10010033200
#
# 55200
# 11300
# 143200
# 78300
# 165400
# 187300
# 121300
# 55300
# 11400
# 33300
# 210500100200
# 143300
#
# 78400
# 165500
# 187400
# 121400
# 55400
# 3340011500210600
#
# 100300
#
# 143400
# 78500
# 187500
# 165600
# 121500
# 55500
# 210700
# 100400
# 33500
# 143500
# 11600
# 78600
# 187600
# 165700
# 121600
# 55600
# 100500
# 210800
# 11700
# 143600
# 33600
# 165800
# 187700
# 78700
# 121700
# 55700
# 210900
# 100600
# 11800
# 14370078800
#
# 165900
# 33700
# 187800
# 121800
# 55800
# 100700
# 211000
# 78900
# 11900
# 33800
# 143800
# 166000
# 187900
# 121900
# 55900
# 100800
# 211100
# 79000
# 12000
# 143900
# 33900
# 166100
# 188000122000
#
# 56000
# 211200
# 100900
# 79100
# 34000
# 12100
# 122100144000188100
# 166200
#
#
# 56100
# 211300
# 101000
# 79200
# 3410012200
#
# 122200
# 144100166300
#
# 188200
# 101100
# 56200
# 211400
# 79300
# 122300
# 79400
# 12300
# 166400
# 211500
# 144200101200
#
# 34200
# 188300
# 56300
# 1013007950012400
#
#
# 211600
# 144300
# 122400
# 188400
# 166500
# 3430056400
# 79600101400
#
# 211700
# 12500
# 1885001444001225005650034400
#
#
#
#
# 166600
# 79700101500
#
# 211800
# 12600
# 16670056600188600144500
# 34500
#
#
# 122600
#
# 79800101600
#
# 211900
# 34600
# 1270056700
# 122700144600
#
#
# 188700166800
#
# 79900101700
#
# 212000
# 12800122800
# 188800144700
#
# 5680016690034700
#
#
#
# 80000
# 101800
# 212100
# 122900
# 144800
# 1889001290034800
# 167000
#
#
# 56900
# 80100
# 101900
# 212200
# 144900189000123000
#
# 13000167100
#
#
# 57000
# 34900
# 10200080200
#
# 212300
# 1310057100
#
# 102100
# 8030035000
# 189100123100
#
# 167200
#
# 145000
# 212400
# 167300145100189200
#
#
# 5720035100102200123200
# 80400
#
#
# 13200
#
# 212500
# 13300
# 102300
# 5730080500
# 21260014520016740035200
# 189300
#
#
#
#
# 123300
# 80600
# 212700
# 35300189400
# 10240013400
#
# 167500
#
# 145300
# 123400
# 57400
# 80700
# 212800
# 102500
# 13500
# 123500
# 1895001676003540057500145400
#
#
#
#
# 80800
# 212900
# 102600
# 5760035500145500
# 13600
# 167700
#
# 189600
#
# 123600
# 80900
# 213000
# 102700
# 189700
# 167800
# 577003560013700
#
#
# 145600123700
#
# 81000
# 213100
# 102800
# 189800123800
#
# 167900
# 3570013800
# 145700
#
# 57800
# 21320081100
#
# 102900
# 12390018990035800
#
# 145800
# 16800013900
#
#
# 57900
# 213300
# 81200
# 103000
# 124000213400
# 81300
#
# 103100
# 19000014000
# 35900
# 14590058000
#
#
# 168100
# 213500
# 81400
# 14100146000
#
# 124100
# 190100
# 10320036000168200
#
#
# 58100
# 213600
# 81500
# 190200
# 582001420036100
#
# 124200
# 103300
# 146100
# 168300
#
# 213700
# 81600
# 103400
# 124300
# 14300
# 146200
# 190300168400
# 58300
#
# 36200
# 213800
# 81700
# 103500
# 124400
# 146300
# 14400
# 58400
# 168500
# 36300190400
#
# 213900
# 81800
# 103600
# 124500
# 14500
# 146400
# 190500
# 819005850036400
#
# 168600
# 214000
#
# 103700
# 124600
# 14650014600
#
# 36500190600
# 168700
# 82000
#
# 58600214100
#
# 103800
# 124700
# 146600
# 14700
# 214200
# 82100190700
# 168800
#
# 3660058700103900
#
#
# 124800
# 146700
# 14800
# 214300104000168900
#
#
# 5880082200
# 190800
#
# 36700
# 124900
# 146800
# 14900
# 21440019090082300
#
#
# 58900104100
#
# 16900036800125000
#
#
# 146900
# 15000
# 125100214500
#
# 82400
# 59000169100
# 191000
# 36900
# 104200
#
# 147000
# 15100
# 214600
# 82500
# 125200
# 191100104300
#
# 16920037000
#
# 59100
# 147100
# 15200
# 82600
# 214700
# 104400
# 125300
# 37100
# 169300191200
# 59200
#
# 147200
# 15300
# 82700
# 214800
# 104500
# 125400
# 59300
# 37200
# 169400191300
#
# 147300
# 15400
# 82800
# 214900
# 104600
# 125500
# 59400
# 169500
# 3730019140015500
#
# 147400
#
# 82900
# 215000
# 104700
# 125600
# 169600147500191500
# 37400
# 59500
#
#
# 15600
# 83000
# 215100
# 104800
# 125700
# 15700
# 191600
# 37500
# 14760083100
#
# 59600
# 169700
# 215200104900
#
# 125800
# 15800
# 191700
# 8320037600147700
#
# 59700
# 169800215300
#
#
# 105000
# 125900
# 15900
# 105100191800
# 21540037700
# 147800
#
# 8330059800169900
#
#
# 126000
#
# 16000
# 105200
# 17000012610059900
# 14790037800191900215500
#
#
#
# 83400
#
#
# 16100
# 105300
# 3790021560012620083500170100
#
#
# 192000148000
#
#
#
# 60000
# 16200
# 105400
# 17020038000
#
# 19210060100
# 126300
# 148100
# 83600
#
# 215700
# 16300
# 105500
# 6020019220083700
#
# 170300
#
# 215800
# 148200
# 126400
# 38100
# 16400
# 105600
# 148300
# 126500
# 215900
# 192300
# 83800
# 1704001650038200
#
#
# 60300
# 105700
# 83900
# 216000
# 16600148400
#
# 3830060400
#
# 126600
# 170500
# 192400
# 105800
# 216100
# 84000
# 38400
# 16700148500
#
# 60500192500
# 170600
#
# 126700
# 105900
# 84100
# 38500170700
#
# 216200
# 192600
# 60600
# 126800106000
# 14860016800
#
#
# 84200
# 216300
# 106100
# 126900
# 60700192700
# 148700170800
#
#
# 38600
# 16900
# 84300
# 106200216400
#
# 127000
# 60800
# 170900
# 14880019280038700
#
# 17000
#
# 84400
# 216500
# 106300
# 12710017100
#
# 148900171000192900
#
#
# 38800
# 60900
# 216600
# 84500
# 106400
# 17200127200
#
# 149000
# 38900
# 193000
# 61000
# 171100
# 21670084600
#
# 106500
# 193100
# 17120061100
#
# 127300
# 149100
# 17300
# 39000
# 84700216800
#
# 106600
# 1740061200149200
#
#
# 19320084800171300106700127400
# 39100
#
#
#
#
# 216900
# 3920084900
#
# 171400106800
# 217000193300
#
#
# 12750014930017500
#
#
# 61300
# 106900
# 1494008500061400
#
# 2171003930017600
#
# 171500
#
# 127600
# 193400
#
# 85100107000
# 14950039400127700
# 17700
#
# 21720019350061500
#
#
#
# 171600
#
# 107100
# 149600127800
#
# 21730085200
#
# 6160039500193600
#
# 171700
#
# 17800
# 107200
# 217400
# 14970061700
# 85300
# 39600
# 17900
#
# 171800127900
#
# 193700
# 85400128000149800
#
#
# 107300
# 171900
# 618002175001800039700
# 193800
